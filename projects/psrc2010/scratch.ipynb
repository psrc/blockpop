# %%
import us
import geopandas as gpd

# %%
gdf = gpd.read_file('https://www2.census.gov/geo/tiger/TIGER2009/53_WASHINGTON/tl_2009_53_puma500.zip')

# %%
gdf
# Out:
#    STATEFP00 PUMA5CE00 PUMA5ID00  NAMELSAD00 MTFCC00 FUNCSTAT00      ALAND00  \
# 0         53     00400   5300400  PUMA 00400   G6120          S  33659119541
# 1         53     01600   5301600  PUMA 01600   G6120          S  11658435354
# 2         53     01300   5301300  PUMA 01300   G6120          S    129288574
# 3         53     01401   5301401  PUMA 01401   G6120          S    368074223
# 4         53     01402   5301402  PUMA 01402   G6120          S    289296232
# 5         53     01403   5301403  PUMA 01403   G6120          S     76895202
# 6         53     01404   5301404  PUMA 01404   G6120          S   3461172695
# 7         53     01500   5301500  PUMA 01500   G6120          S  13563403587
# 8         53     00100   5300100  PUMA 00100   G6120          S   5456695270
# 9         53     00300   5300300  PUMA 00300   G6120          S  31870820290
# 10        53     00800   5300800  PUMA 00800   G6120          S   7620024942
# ...
